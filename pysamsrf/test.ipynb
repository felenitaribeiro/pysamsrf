# %%
from pysamsrf.io.aperture_io import load_apertures

apertures = load_apertures('/Users/ribeiroadmin/Projects/pysamsrf/samsrf/pysamsrf/data/apertures_samsrf/aps_retbars.mat')
apertures['apertures'].shape

# %%
apertures['apertures'].shape
# Out:
# (100, 100, 300)

# %%
from pysamsrf.io import load_surface, save_surface

# Load GIFTI surface
srf = load_surface('/Users/ribeiroadmin/neurodesktop-storage/new_data/sub-01_ses-01_task-fixedbar_run-1_space-T1w_desc-preproc_bold_depth-0.0.func.gii')
# Out:
# (221709, 1)
# (221709,)
# (221709, 2)
# (221709,)
# (221709, 3)
# (221709,)
# (221709, 4)
# (221709,)
# (221709, 5)
# (221709,)
# (221709, 6)
# (221709,)
# (221709, 7)
# (221709,)
# (221709, 8)
# (221709,)
# (221709, 9)
# (221709,)
# (221709, 10)
# (221709,)
# (221709, 11)
# (221709,)
# (221709, 12)
# (221709,)
# (221709, 13)
# (221709,)
# (221709, 14)
# (221709,)
# (221709, 15)
# (221709,)
# (221709, 16)
# (221709,)
# (221709, 17)
# (221709,)
# (221709, 18)
# (221709,)
# (221709, 19)
# (221709,)
# (221709, 20)
# (221709,)
# (221709, 21)
# (221709,)
# (221709, 22)
# (221709,)
# (221709, 23)
# (221709,)
# (221709, 24)
# (221709,)
# (221709, 25)
# (221709,)
# (221709, 26)
# (221709,)
# (221709, 27)
# (221709,)
# (221709, 28)
# (221709,)
# (221709, 29)
# (221709,)
# (221709, 30)
# (221709,)
# (221709, 31)
# (221709,)
# (221709, 32)
# (221709,)
# (221709, 33)
# (221709,)
# (221709, 34)
# (221709,)
# (221709, 35)
# (221709,)
# (221709, 36)
# (221709,)
# (221709, 37)
# (221709,)
# ...

# %%
srf.y.shape
# Out:
# (221709, 305)

# %%
import nibabel as nib

bla = nib.load('/Users/ribeiroadmin/neurodesktop-storage/new_data/sub-01_ses-01_task-fixedbar_run-1_space-T1w_desc-preproc_bold_depth-0.0.func.gii')

# %%
for darray in bla.darrays:
        intent = darray.intent
        print(intent)
# Out:
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# ...
